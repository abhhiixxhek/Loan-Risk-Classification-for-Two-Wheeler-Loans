# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('/content/Assignment_Train.csv')
df2 = pd.read_csv('/content/Assignment_Test.csv')
df3 = pd.read_excel('/content/Assignment_FeatureDictionary.xlsx')

# %%
df1
# Out:
#       DEALER ID APPLICATION LOGIN DATE HDB BRANCH NAME HDB BRANCH STATE  \
# 0        106989             07/20/2022        DELHI-SF            DELHI
# 1        108975             07/28/2022        PATNA-SF            BIHAR
# 2        111004             07/15/2022   DARJEELING-SF      WEST BENGAL
# 3        192020               07/04/22   SAHARANPUR-SF    UTTAR PRADESH
# 4         55095             07/15/2022       MODASA-SF          GUJARAT
# ...         ...                    ...             ...              ...
# 9995     105101               07/11/22  FARRUKHABAD-SF    UTTAR PRADESH
# 9996      85054               07/04/22    BHAGALPUR-SF            BIHAR
# 9997      53710               07/10/22     LUDHIANA-SF           PUNJAB
# 9998      89240             07/29/2022       MEERUT-SF    UTTAR PRADESH
# 9999     109455             07/14/2022      ALIGARH-SF    UTTAR PRADESH
#
#      FIRST NAME MIDDLE NAME  LAST NAME      mobile AADHAR VERIFIED  \
# ...

# %%
df2
# Out:
#                       UID  DEALER ID APPLICATION LOGIN DATE HDB BRANCH NAME  \
# 0     1844045271814558464     105615               07/12/22        HUBLI-SF
# 1     1840349097823778816      91593             07/14/2022        SATNA-SF
# 2     1488102613362294272      74152               07/07/22      LUCKNOW-SF
# 3      555529923942874624     110164             07/13/2022       KOLLAM-SF
# 4     1010213070486150912     113037               07/08/22         PURI-SF
# ...                   ...        ...                    ...             ...
# 1995  1595862360559879424     110697             07/25/2022      LUCKNOW-SF
# 1996   879889749720017664     107225             07/21/2022    SHUJALPUR-SF
# 1997   242909456443720192      92743             07/19/2022        NOIDA-SF
# 1998   138725642700761856     193608               07/07/22    DARBHANGA-SF
# 1999  1680321200653072640      84909             07/24/2022       SUPAUL-SF
#
# ...

# %%
df3
# Out:
#                             COLUMN NAME  \
# 0                             DEALER ID
# 1                APPLICATION LOGIN DATE
# 2                       HDB BRANCH NAME
# 3                      HDB BRANCH STATE
# 4                            FIRST NAME
# 5                           MIDDLE NAME
# 6                             LAST NAME
# 7                                mobile
# 8                       AADHAR VERIFIED
# 9                           Cibil Score
# 10                  MOBILE VERIFICATION
# 11                          DEALER NAME
# 12                     TOTAL ASSET COST
# 13                            ASSET CTG
# 14                       ASSET MODEL NO
# 15                               LOS ID
# 16                       APPLIED AMOUNT
# 17                   PRIMARY ASSET MAKE
# 18               Primary Asset Model No
# 19               Personal Email Address
# 20                       MARITAL STATUS
# 21                               GENDER
# ...

# %%
df1.describe()
# Out:
#            DEALER ID        mobile  TOTAL ASSET COST  ASSET MODEL NO  \
# count   10000.000000  1.000000e+04       4892.000000    10000.000000
# mean   102936.459100  8.630041e+09      97612.518397   150660.758500
# std     37830.984431  1.077717e+09      16745.027041    20847.995017
# min     49849.000000  6.000042e+09      51873.000000   124587.000000
# 25%     79953.750000  7.894858e+09      88425.500000   139542.000000
# 50%     94631.000000  8.867377e+09      94400.000000   143238.000000
# 75%    108463.000000  9.588181e+09     103499.250000   160216.000000
# max    202616.000000  9.999977e+09     241116.000000   201897.000000
#
#        APPLIED AMOUNT           DOB           AGE  \
# count    1.000000e+04  1.000000e+04  10000.000000
# mean     9.179673e+04  9.813396e+06     31.796100
# std      2.700018e+04  8.930654e+06     11.202075
# min      1.040000e+04  1.011943e+06      0.000000
# 25%      8.000000e+04  1.012000e+06     25.000000
# ...

# %%
df2.describe()
# Out:
#                 UID      DEALER ID        mobile  TOTAL ASSET COST  \
# count  2.000000e+03    2000.000000  2.000000e+03        978.000000
# mean   1.130746e+18  104662.633000  8.615985e+09      97679.605317
# std    6.679230e+17   38583.383585  1.090403e+09      16353.421097
# min    5.503943e+11   49849.000000  6.000084e+09      53249.000000
# 25%    5.377231e+17   81981.250000  7.858379e+09      88939.500000
# 50%    1.108497e+18   94964.000000  8.859302e+09      94535.500000
# 75%    1.724955e+18  108974.250000  9.568866e+09     103354.250000
# max    2.303354e+18  201748.000000  9.999919e+09     277508.000000
#
#        ASSET MODEL NO  APPLIED AMOUNT           DOB         AGE  \
# count     2000.000000    2.000000e+03  2.000000e+03  2000.00000
# mean    151598.707000    9.372890e+04  9.897133e+06    32.35800
# std      21615.502147    4.728632e+04  9.112755e+06    11.00838
# min     124587.000000    1.004100e+04  1.011960e+06     0.00000
# ...

# %%
df3.describe()
# Out:
#        COLUMN NAME COLUMN DESCRIPTION
# count           56                 25
# unique          56                 23
# top      DEALER ID  Submitted Details
# freq             1                  2

# %%
col =df1.columns

# %%
for i in col:
    print(df1[i].value_counts())
# Out:
# DEALER ID
# 112006    75
# 88282     51
# 77503     39
# 79245     38
# 94718     37
#           ..
# 64913      1
# 75434      1
# 55335      1
# 199676     1
# 105111     1
# Name: count, Length: 2416, dtype: int64
# APPLICATION LOGIN DATE
# 07/11/22      505
# 07/13/2022    469
# 07/18/2022    468
# 07/04/22      438
# 07/25/2022    414
# 07/15/2022    409
# 07/07/22      400
# 07/08/22      374
# 07/14/2022    373
# 07/22/2022    370
# 07/19/2022    364
# 07/06/22      361
# 07/12/22      359
# 07/21/2022    358
# 07/27/2022    355
# 07/20/2022    354
# 07/26/2022    351
# 07/29/2022    349
# 07/05/22      347
# 07/28/2022    337
# 07/09/22      282
# 07/30/2022    282
# 07/31/2022    262
# 07/17/2022    254
# 07/16/2022    243
# 07/03/22      241
# 07/10/22      233
# 07/23/2022    231
# 07/24/2022    217
# Name: count, dtype: int64
# HDB BRANCH NAME
# NOIDA-SF          306
# DELHI-SF          239
# HYDERABAD-SF      210
# DEHRADUN-SF       200
# BANGALORE-SF      147
# ...

# %%
#Feature Extraction
feature = ['Cibil Score', 'TOTAL ASSET COST', 'APPLIED AMOUNT', 'MARITAL STATUS', 'GENDER', 'vpa', 'ADDRESS TYPE', 'EMPLOYER TYPE', 'phone_digitalage', 'phone_nameMatchScore', 'phone_phoneFootprintStrengthOverall']

# %%
final_df1 = pd.DataFrame()
final_df2 = pd.DataFrame()

# Loop through each feature in the list 'feature'
for i in feature:
    # Concatenate the specified column from df1 to final_df1
    # This adds the column from df1 to final_df1 along the columns axis (axis=1)
    final_df1 = pd.concat([final_df1, df1[i]], axis=1)  # Assign the result back to final_df1

    # Similarly, concatenate the specified column from df2 to final_df2
    final_df2 = pd.concat([final_df2, df2[i]], axis=1)  # Assign the result back to final_df2

# Create DataFrame 'is_null1' that contains only the first column from final_df1
# This will be used to check for null values or other analysis
is_null1 = pd.DataFrame(final_df1.iloc[:, 0])

# Similarly, create DataFrame 'is_null2' that contains only the first column from final_df2
# This will be used to check for null values or other analysis
is_null2 = pd.DataFrame(final_df2.iloc[:, 0])

# %%
final_df1.info()
final_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Cibil Score                          5703 non-null   object
#  1   TOTAL ASSET COST                     4892 non-null   float64
#  2   APPLIED AMOUNT                       10000 non-null  int64
#  3   MARITAL STATUS                       5106 non-null   object
#  4   GENDER                               10000 non-null  object
#  5   vpa                                  7213 non-null   object
#  6   ADDRESS TYPE                         6688 non-null   object
#  7   EMPLOYER TYPE                        5002 non-null   object
#  8   phone_digitalage                     9996 non-null   float64
#  9   phone_nameMatchScore                 9996 non-null   float64
#  10  phone_phoneFootprintStrengthOverall  9994 non-null   object
# ...

# %%
is_null1
is_null2
# Out:
#      Cibil Score
# 0            757
# 1            750
# 2            710
# 3            695
# 4            NaN
# ...          ...
# 1995         734
# 1996         727
# 1997         675
# 1998         741
# 1999         NaN
#
# [2000 rows x 1 columns]

# %%
# Iterate over each row index in final_df1
for i in range(final_df1.shape[0]):
    # Check if there is any NaN value in the current row of final_df1
    if final_df1.iloc[i].isna().any():
        # If NaN is present, set the corresponding value in is_null1 to True
        is_null1.iloc[i] = True
    else:
        # If no NaN is present, set the corresponding value in is_null1 to False
        is_null1.iloc[i] = False

# Iterate over each row index in final_df2
for i in range(final_df2.shape[0]):
    # Check if there is any NaN value in the current row of final_df2
    if final_df2.iloc[i].isna().any():
        # If NaN is present, set the corresponding value in is_null2 to True
        is_null2.iloc[i] = True
    else:
        # If no NaN is present, set the corresponding value in is_null2 to False
        is_null2.iloc[i] = False

# %%
is_null1.columns=['is_null']
is_null2.columns=['is_null']

# %%
final_df1 = pd.concat([final_df1,is_null1],axis=1)
final_df2 = pd.concat([final_df2,is_null2],axis=1)

# %%
final_df1.columns
# Out:
# Index(['Cibil Score', 'TOTAL ASSET COST', 'APPLIED AMOUNT', 'MARITAL STATUS',
#        'GENDER', 'vpa', 'ADDRESS TYPE', 'EMPLOYER TYPE', 'phone_digitalage',
#        'phone_nameMatchScore', 'phone_phoneFootprintStrengthOverall',
#        'is_null'],
#       dtype='object')

# %%
final_df2.columns
# Out:
# Index(['Cibil Score', 'TOTAL ASSET COST', 'APPLIED AMOUNT', 'MARITAL STATUS',
#        'GENDER', 'vpa', 'ADDRESS TYPE', 'EMPLOYER TYPE', 'phone_digitalage',
#        'phone_nameMatchScore', 'phone_phoneFootprintStrengthOverall',
#        'is_null'],
#       dtype='object')

# %%
final_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Cibil Score                          5703 non-null   object
#  1   TOTAL ASSET COST                     4892 non-null   float64
#  2   APPLIED AMOUNT                       10000 non-null  int64
#  3   MARITAL STATUS                       5106 non-null   object
#  4   GENDER                               10000 non-null  object
#  5   vpa                                  7213 non-null   object
#  6   ADDRESS TYPE                         6688 non-null   object
#  7   EMPLOYER TYPE                        5002 non-null   object
#  8   phone_digitalage                     9996 non-null   float64
#  9   phone_nameMatchScore                 9996 non-null   float64
#  10  phone_phoneFootprintStrengthOverall  9994 non-null   object
# ...

# %%
final_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Cibil Score                          1158 non-null   object
#  1   TOTAL ASSET COST                     978 non-null    float64
#  2   APPLIED AMOUNT                       2000 non-null   int64
#  3   MARITAL STATUS                       1019 non-null   object
#  4   GENDER                               2000 non-null   object
#  5   vpa                                  1446 non-null   object
#  6   ADDRESS TYPE                         1365 non-null   object
#  7   EMPLOYER TYPE                        1006 non-null   object
#  8   phone_digitalage                     2000 non-null   int64
#  9   phone_nameMatchScore                 2000 non-null   float64
#  10  phone_phoneFootprintStrengthOverall  1999 non-null   object
# ...

# %%
# Initialize an empty list to store the names of columns with dtype 'object'
col_tran = []

# Loop through each column name in final_df1
for i in final_df1.columns:
    # Check if the data type of the current column is 'object'
    if final_df1[i].dtype == object:
        # If true, append the column name to the col_tran list
        col_tran.append(i)

# %%
for i in final_df1.columns:
    print(final_df1[i].value_counts())
# Out:
# Cibil Score
# 752    105
# 726     91
# 743     88
# 746     87
# 767     81
#       ...
# 586      1
# 577      1
# 570      1
# 537      1
# 817      1
# Name: count, Length: 267, dtype: int64
# TOTAL ASSET COST
# 98000.0     13
# 106500.0    12
# 98300.0     11
# 94000.0     10
# 104000.0    10
#             ..
# 112231.0     1
# 150340.0     1
# 86743.0      1
# 103013.0     1
# 101262.0     1
# Name: count, Length: 3692, dtype: int64
# APPLIED AMOUNT
# 90000    852
# 85000    836
# 95000    634
# 80000    593
# 99000    542
#         ...
# 89797      1
# 93352      1
# 95632      1
# 53500      1
# 96471      1
# Name: count, Length: 1230, dtype: int64
# MARITAL STATUS
# Married    3833
# Single     1273
# Name: count, dtype: int64
# GENDER
# Male      8408
# Female    1592
# Name: count, dtype: int64
# vpa
# YBL                1451
# OKSBI              1025
# PAYTM               877
# OKAXIS              696
# OKICICI             673
# OKHDFCBANK          658
# ...

# %%
# Replace boolean True with 1 in final_df1
final_df1 = final_df1.replace(True, 1)

# Replace boolean False with 0 in final_df1
final_df1 = final_df1.replace(False, 0)

# Replace the string "Male" with 0 in final_df1
final_df1 = final_df1.replace("Male", 0)

# Replace the string "Female" with 1 in final_df1
final_df1 = final_df1.replace("Female", 1)

# Repeat the above replacement steps for final_df2
final_df2 = final_df2.replace(True, 1)
final_df2 = final_df2.replace(False, 0)
final_df2 = final_df2.replace("Male", 0)
final_df2 = final_df2.replace("Female", 1)

# %%
final_df1
# Out:
#      Cibil Score  TOTAL ASSET COST  APPLIED AMOUNT MARITAL STATUS  GENDER  \
# 0            726           95041.0           85000        Married       0
# 1            NaN               NaN           90000            NaN       0
# 2            737          119436.0           75000         Single       0
# 3            713           87000.0           78500         Single       0
# 4            669               NaN           70000            NaN       0
# ...          ...               ...             ...            ...     ...
# 9995         NaN           88970.0           87000        Married       0
# 9996         NaN          120000.0           90000        Married       0
# 9997         NaN           89929.0           89000        Married       0
# 9998         NaN           89340.0           85000        Married       0
# 9999         761          101262.0           85000        Married       0
#
#           vpa       ADDRESS TYPE  EMPLOYER TYPE  phone_digitalage  \
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# Initialize SimpleImputer with strategy to replace missing values with the most frequent value in the column
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
col_tran=[]
for i in final_df1.columns :
    if final_df1[i].dtype== object:
        col_tran.append(i)

# %%
final_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Cibil Score                          5703 non-null   object
#  1   TOTAL ASSET COST                     4892 non-null   float64
#  2   APPLIED AMOUNT                       10000 non-null  int64
#  3   MARITAL STATUS                       5106 non-null   object
#  4   GENDER                               10000 non-null  int64
#  5   vpa                                  7213 non-null   object
#  6   ADDRESS TYPE                         6688 non-null   object
#  7   EMPLOYER TYPE                        5002 non-null   object
#  8   phone_digitalage                     9996 non-null   float64
#  9   phone_nameMatchScore                 9996 non-null   float64
#  10  phone_phoneFootprintStrengthOverall  9994 non-null   object
# ...

# %%
# Replace missing "Cibil Score" values with 10000 in final_df1
# This is done to ensure that missing values do not impact further analysis and to provide a default value.
final_df1["Cibil Score"].fillna(10000, inplace=True)

# Replace missing "Cibil Score" values with 10000 in final_df2
# This helps maintain consistency between datasets and prevents issues in subsequent analyses.
final_df2["Cibil Score"].fillna(10000, inplace=True)

# %%
# Replace "NO RESPONSE" and "-" with 10000 in the "Cibil Score" column of final_df1
# These entries represent invalid or missing values, so we replace them with a default value to avoid data issues.
final_df1['Cibil Score'].replace("NO RESPONSE", 10000, inplace=True)
final_df1['Cibil Score'].replace("-", 10000, inplace=True)

# Replace "NO RESPONSE" and "-" with 10000 in the "Cibil Score" column of final_df2
# This ensures consistency in handling missing or invalid data for easier processing.
final_df2['Cibil Score'].replace("NO RESPONSE", 10000, inplace=True)
final_df2['Cibil Score'].replace("-", 10000, inplace=True)

# %%
# Iterate over each row in final_df1 to convert "Cibil Score" values to integers
for i in range(final_df1.shape[0]):
    try:
        # Attempt to convert the current value of "Cibil Score" to an integer
        final_df1['Cibil Score'].iloc[i] = int(final_df1['Cibil Score'].iloc[i])
    except:
        # If conversion fails, print the problematic value
        print(final_df1['Cibil Score'].iloc[i])

# Repeat the same process for final_df2
for i in range(final_df2.shape[0]):
    try:
        # Attempt to convert the current value of "Cibil Score" to an integer
        final_df2['Cibil Score'].iloc[i] = int(final_df2['Cibil Score'].iloc[i])
    except:
        # If conversion fails, print the problematic value
        print(final_df2['Cibil Score'].iloc[i])

# %%
# Replace 10000 with 470 in the "Cibil Score" column of final_df1
# 10000 was likely used as a placeholder for missing or invalid values; now replacing it with a more reasonable value (470).
final_df1['Cibil Score'].replace(10000, 470, inplace=True)

# Replace 10000 with 470 in the "Cibil Score" column of final_df2
# Ensures consistency by replacing the placeholder value 10000 with 470 in both datasets.
final_df2['Cibil Score'].replace(10000, 470, inplace=True)

# %%
# Fill missing values in the "TOTAL ASSET COST" column of final_df1 with 50000
# Using 100000 as a default value to handle missing data and prevent issues in further analysis or model training.
final_df1['TOTAL ASSET COST'].fillna(100000, inplace=True)

# Fill missing values in the "TOTAL ASSET COST" column of final_df2 with 100000
# Ensures both datasets have no missing values in this column and are consistent for processing.
final_df2['TOTAL ASSET COST'].fillna(100000, inplace=True)

# %%
# Fill missing values in the "MARITAL STATUS" column of final_df1 with "Single"
# This assumes "Single" as a default for missing values, likely based on the assumption that most missing entries belong to this category.
final_df1['MARITAL STATUS'].fillna("Single", inplace=True)

# Fill missing values in the "MARITAL STATUS" column of final_df2 with "Single"
# Ensures consistent handling of missing data across both datasets.
final_df2['MARITAL STATUS'].fillna("Single", inplace=True)

# %%
# Apply the SimpleImputer to final_df1 to fill missing values based on the most frequent value
# This step replaces missing values across all columns with the most frequent value in each column.
trial1 = imp_mean.fit_transform(final_df1)
trial2 = imp_mean.fit_transform(final_df2)

# %%
data1=pd.DataFrame(trial1)
data2=pd.DataFrame(trial2)

# %%
data1.columns=final_df1.columns
data2.columns=final_df1.columns

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Cibil Score                          2000 non-null   object
#  1   TOTAL ASSET COST                     2000 non-null   object
#  2   APPLIED AMOUNT                       2000 non-null   object
#  3   MARITAL STATUS                       2000 non-null   object
#  4   GENDER                               2000 non-null   object
#  5   vpa                                  2000 non-null   object
#  6   ADDRESS TYPE                         2000 non-null   object
#  7   EMPLOYER TYPE                        2000 non-null   object
#  8   phone_digitalage                     2000 non-null   object
#  9   phone_nameMatchScore                 2000 non-null   object
#  10  phone_phoneFootprintStrengthOverall  2000 non-null   object
# ...

# %%
for col in data1.columns :
    try :
        data1[col]=data1[col].astype(float)
        data2[col]=data2[col].astype(float)
    except :
        pass

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
col_tran=[]
for i in data1.columns :
    if data1[i].dtype== object:
        col_tran.append(i)

# %%
cat1=enc.fit_transform(data1[col_tran])
cat2=enc.fit_transform(data2[col_tran])

# %%
cat2=pd.DataFrame(cat2)
cat1=pd.DataFrame(cat1)

# %%
cat1.columns=col_tran
cat2.columns=col_tran
data1[col_tran]=cat1
data2[col_tran]=cat2

# %%
ans=df1['Application Status']

# %%
ans.replace("APPROVED",1,inplace=True)
ans.replace("DECLINED",0,inplace=True)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data1.drop('is_null', axis=1), ans, test_size=0.2, random_state=42)

# Create a Random Forest classifier
rf_classifier = RandomForestClassifier(random_state=42)

# Define the hyperparameter grid for tuning
param_grid = {
    'n_estimators': [100, 200, 500],         # Number of trees
    'max_depth': [10, 20, 30, None],         # Depth of trees
    'min_samples_split': [2, 5, 10],         # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4],           # Minimum number of samples required at each leaf node
    'max_features': ['sqrt', 'log2', None]   # Number of features to consider when looking for the best split
}

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid,
                           cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Perform grid search on the training data
grid_search.fit(X_train, y_train)

# Best parameters found
print("Best Parameters found:", grid_search.best_params_)

# Train the model with the best parameters
best_rf_classifier = grid_search.best_estimator_

# Evaluate with cross-validation on the training set
cv_scores = cross_val_score(best_rf_classifier, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", cv_scores)
print("Mean cross-validation accuracy:", cv_scores.mean())

# Make predictions on the test set with the best model
y_pred = best_rf_classifier.predict(X_test)

# Evaluate the model on the test set
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Parameters found: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Cross-validation accuracy scores: [0.874375 0.863125 0.894375 0.874375 0.870625]
# Mean cross-validation accuracy: 0.875375
# Test Accuracy: 0.8635

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_prob_rf = best_rf_classifier.predict_proba(X_test)[:, 1]

# Calculate the AUC-ROC
roc_auc_rf = roc_auc_score(y_test, y_pred_prob_rf)
print(f"Random Forest AUC-ROC: {roc_auc_rf:.4f}")

# Plot the ROC curve
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_pred_prob_rf)
plt.figure(figsize=(8, 6))
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest (AUC = {roc_auc_rf:.4f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend(loc='lower right')
plt.show()


from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['DECLINED', 'APPROVED'], yticklabels=['DECLINED', 'APPROVED'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Random Forest AUC-ROC: 0.9503

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Define the hyperparameter grid for tuning
param_grid_xgb = {
    'n_estimators': [100, 200, 500],           # Number of boosting rounds
    'max_depth': [3, 6, 10],                   # Maximum depth of a tree
    'learning_rate': [0.01, 0.1, 0.2],         # Learning rate
    'subsample': [0.8, 1.0],                   # Subsample ratio of the training instances
    'colsample_bytree': [0.8, 1.0],            # Subsample ratio of columns when constructing each tree
    'gamma': [0, 0.1, 0.3],                    # Minimum loss reduction required to make a further partition
}

# Create an XGBoost classifier
xgb_classifier = XGBClassifier(random_state=42)

# Initialize GridSearchCV with 5-fold cross-validation
grid_search_xgb = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid_xgb,
                               cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Perform grid search on the training data
grid_search_xgb.fit(X_train, y_train)

# Best parameters found
print("Best Parameters found:", grid_search_xgb.best_params_)

# Train the model with the best parameters
best_xgb_classifier = grid_search_xgb.best_estimator_

# Evaluate with cross-validation on the training set
cv_scores_xgb = cross_val_score(best_xgb_classifier, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", cv_scores_xgb)
print("Mean cross-validation accuracy:", cv_scores_xgb.mean())

# Make predictions on the test set with the best model
y_pred_xgb = best_xgb_classifier.predict(X_test)

# Evaluate the model on the test set
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print("Test Accuracy (XGBoost):", accuracy_xgb)

# Calculate the confusion matrix
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

# Predict probabilities for the test set
y_pred_prob_xgb = best_xgb_classifier.predict_proba(X_test)[:, 1]

# Calculate the AUC-ROC
roc_auc_xgb = roc_auc_score(y_test, y_pred_prob_xgb)
print(f"XGBoost AUC-ROC: {roc_auc_xgb:.4f}")

# Plot the ROC curve
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_pred_prob_xgb)
plt.figure(figsize=(8, 6))
plt.plot(fpr_xgb, tpr_xgb, label=f"XGBoost (AUC = {roc_auc_xgb:.4f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - XGBoost')
plt.legend(loc='lower right')
plt.show()


# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_xgb, annot=True, fmt="d", cmap="Blues",
            xticklabels=['DECLINED', 'APPROVED'], yticklabels=['DECLINED', 'APPROVED'])
plt.title("XGBoost Confusion Matrix", fontsize=16, fontweight='bold')
plt.xlabel("Predicted Labels", fontsize=12)
plt.ylabel("True Labels", fontsize=12)
plt.show()
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Parameters found: {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Cross-validation accuracy scores: [0.8825   0.86375  0.884375 0.8775   0.8725  ]
# Mean cross-validation accuracy: 0.876125
# Test Accuracy (XGBoost): 0.869
# XGBoost AUC-ROC: 0.9505

# %%
from tensorflow.keras.preprocessing import text
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, GlobalMaxPooling1D, Bidirectional, SpatialDropout1D, LSTM, GRU, SimpleRNN, Dense, Activation, Dropout, Embedding, BatchNormalization, TextVectorization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
import spacy
import warnings
from tqdm import tqdm
warnings.filterwarnings('ignore')

# %%
#test train split
X_train, X_val, y_train, y_val = train_test_split(data1, ans, test_size=0.7,random_state=25)
from tensorflow.keras.layers import *

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Activation, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

# Create the model
model = Sequential()

# Input layer and first hidden layer
model.add(Dense(256, input_shape=(X_train.shape[1],)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))

# Second hidden layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Third hidden layer
model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.4))

# Fourth hidden layer
model.add(Dense(32))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))

# Output layer for binary classification
model.add(Dense(1, activation='sigmoid'))

# Compile the model with the Adam optimizer and a learning rate scheduler
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Callbacks: Early stopping and learning rate reduction on plateau
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=30,
                    batch_size=32,
                    callbacks=[early_stop, reduce_lr])

# Summary of the model
model.summary()
# Out:
# Epoch 1/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.6148 - loss: 0.6426 - val_accuracy: 0.6656 - val_loss: 2.1537 - learning_rate: 0.0010
# Epoch 2/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6999 - loss: 0.5100 - val_accuracy: 0.6417 - val_loss: 1.3016 - learning_rate: 0.0010
# Epoch 3/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6939 - loss: 0.5011 - val_accuracy: 0.6141 - val_loss: 0.8369 - learning_rate: 0.0010
# Epoch 4/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6838 - loss: 0.4964 - val_accuracy: 0.6704 - val_loss: 0.5899 - learning_rate: 0.0010
# Epoch 5/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7026 - loss: 0.4627 - val_accuracy: 0.7240 - val_loss: 0.4620 - learning_rate: 0.0010
# Epoch 6/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7288 - loss: 0.4458 - val_accuracy: 0.6680 - val_loss: 0.4502 - learning_rate: 0.0010
# Epoch 7/30
# ...

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    # Accuracy graph
    plt.figure(figsize=(18, 8))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation accuracy')
    plt.xlabel('Season')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and validation accuracy')
    plt.grid(False)

    # Loss graph
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.xlabel('Season')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.title('Loss of training and validation')
    plt.grid(False)
    plt.show()

# Plot the graphs
plot_history(history)

# %%
preds = np.round(model.predict(X_val)).astype(int)
print("Predictions \n", classification_report(y_val, preds))
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Predictions
#                precision    recall  f1-score   support
#
#            0       0.60      0.98      0.74      2326
#            1       0.99      0.67      0.80      4674
#
#     accuracy                           0.77      7000
#    macro avg       0.79      0.83      0.77      7000
# weighted avg       0.86      0.77      0.78      7000

# %%
#saving model image
import tensorflow as tf
tf.keras.utils.plot_model(model, show_dtype=True,
                       show_layer_names=True, show_shapes=True,
                       to_file='model.png')

# %%
#testing predictions
preds = np.round(model.predict(data2)).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
application=pd.DataFrame(preds)

# %%
ans = pd.concat([df2['UID'], application], axis=1)

# %%
ans.columns=['UID',"Prediction"]

# %%
ans['Prediction'].replace(1,"APPROVED",inplace=True)
ans['Prediction'].replace(0,"DECLINED",inplace=True)

# %%
# saved file
ans.to_csv("predictions.csv")

# %%
pd.read_csv("predictions.csv")
# Out:
#       Unnamed: 0                  UID Prediction
# 0              0  1844045271814558464   APPROVED
# 1              1  1840349097823778816   APPROVED
# 2              2  1488102613362294272   APPROVED
# 3              3   555529923942874624   DECLINED
# 4              4  1010213070486150912   APPROVED
# ...          ...                  ...        ...
# 1995        1995  1595862360559879424   APPROVED
# 1996        1996   879889749720017664   DECLINED
# 1997        1997   242909456443720192   DECLINED
# 1998        1998   138725642700761856   APPROVED
# 1999        1999  1680321200653072640   APPROVED
#
# [2000 rows x 3 columns]

# %%
print('Neural Network Accuracy: %.2f' % (accuracy))
# Out:
# Neural Network Accuracy: 0.77
